# %% [markdown]
# Q1. You are a data analyst at an e-commerce company. Your task is to analyze sales data,
# clean and process it, perform staƟsƟcal analysis, and generate visual insights to help the
# business make informed decisions.
# 1. Use your roll number as the random seed to generate unique data for each student.
# 2. Follow the quesƟons step by step, as each part builds upon the previous one.
# 3. Submit the assignment as a Jupyter Notebook (.ipynb) with:
#  Well-documented code and clear comments.
#  Markdown explanaƟons for each step.
#  Screenshots of the plots and outputs.
# Part I: Randomized Sales Data GeneraƟon (NumPy)
# 1. IniƟalize Random Seed
# 2. Generate Sales Data
#  Create a NumPy array of random sales data for 12 months (shape = (12, 4)),
# where each column represents a product category:
#  Electronics, Clothing, Home & Kitchen, Sports.
#  Sales values should be between 1000 and 5000 units per month.
#  The range should be randomized using the seed.
# 3. Convert to DataFrame
#  Convert the cleaned NumPy array into a Pandas DataFrame with:
# i. Columns: Electronics, Clothing, Home & Kitchen, Sports
# ii. Index: Months from Jan to Dec
# Part II: Data ManipulaƟon and Analysis (Pandas)
# 1. Display the first 5 rows and summary staƟsƟcs of the DataFrame.
# 2. Calculate the total sales per category and total sales per month.
# 3. Calculate the average sales growth between consecuƟve months for each category.
# 4. Add the following columns to the DataFrame:
#  Total Sales: Sum of all categories per month.
#  Growth Rate: Percentage change in Total Sales from the previous month.
# 5. Apply a randomized discount:
#  If your roll number is even, apply a 10% discount to the Electronics category.
#
#  If odd, apply a 15% discount to the Clothing category.
#
# Part III: VisualizaƟons (Matplotlib and Seaborn)
# 1. Plot monthly sales trends for each category using line plots.
# 2. Create the following plots:
#  Box plots to show the sales distribuƟon for each category.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Part I
roll_number = 102317014
np.random.seed(roll_number)
sales_data = np.random.randint(1000,5001,size=(12,4))
categories = ['Electronics','Clothing','Home & Kitchen','Sports']
months = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
df = pd.DataFrame(sales_data,columns=categories,index=months)

# Part II
# 1. Display first 5 rows and summary statistics
print("First 5 rows:")
print(df.head())
print("\nSummary statistics:")
print(df.describe())

# 2. Calculate total sales per category and per month
total_per_category = df.sum(axis=0)        # row sum
print("\nTotal sales per category:")
print(total_per_category)

total_per_month = df.sum(axis=1)           # column sum
print("\nTotal sales per month:")
print(total_per_month)

# 3. Calculate average sales growth between consecutive months for each category
growth_rates = df.pct_change().mean()
print("\nAverage monthly growth rate per category:")
print(growth_rates)

# 4. Add new columns
df['Total Sales'] = df.sum(axis=1)
df['Growth Rate'] = df['Total Sales'].pct_change()*100

# 5. Apply randomized discount
if roll_number % 2 == 0:
    df['Electronics'] = df['Electronics'] * 0.9  # 10% discount
else:
    df['Clothing'] = df['Clothing'] * 0.85  # 15% discount

# Part III
# 1. Monthly sales trends
plt.figure(figsize=(10,6))
for category in categories:
    plt.plot(df.index,df[category],label=category)
plt.title('Monthly Sales Trends by Category')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.legend()
plt.grid()
plt.show()

# 2. Box plots
plt.figure(figsize=(10,6))
sns.boxplot(data=df[categories])
plt.title('Sales Distribution by Category')
plt.ylabel('Sales')
plt.show()
# Out:
# First 5 rows:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         1106      1805            1730    3005
# Feb         3920      1359            3485    3794
# Mar         2801      1074            3615    4641
# Apr         4817      2809            1444    2897
# May         2771      4657            1948    2382
#
# Summary statistics:
#        Electronics     Clothing  Home & Kitchen       Sports
# count    12.000000    12.000000       12.000000    12.000000
# mean   2878.416667  2670.583333     2837.166667  3338.750000
# std    1281.881675  1293.208516     1264.920611   987.477146
# min    1106.000000  1074.000000     1367.000000  1436.000000
# 25%    2148.000000  1455.000000     1751.750000  2832.750000
# 50%    2786.000000  2853.000000     2564.000000  3088.500000
# 75%    3636.500000  3387.000000     3732.500000  4167.750000
# max    4899.000000  4844.000000     4892.000000  4641.000000
#
# Total sales per category:
# Electronics       34541
# Clothing          32047
# Home & Kitchen    34046
# Sports            40065
# dtype: int64
#
# Total sales per month:
# Jan     7646
# Feb    12558
# Mar    12131
# Apr    11967
# May    11758
# Jun    13325
# Jul    10071
# Aug     9857
# Sep    16071
# Oct    11316
# Nov    15243
# Dec     8756
# dtype: int64
#
# Average monthly growth rate per category:
# Electronics       0.244153
# Clothing          0.369158
# Home & Kitchen    0.206221
# Sports            0.143435
# dtype: float64

# %% [markdown]
# Q.2 For the array: array = np.array([[1, -2, 3],[-4, 5, -6]])
#
# i. Find element-wise absolute value
#
# ii. Find the 25th, 50th, and 75th percenƟle of flaƩened array, for each column, for each
# row.
#
# iii. Mean, Median and Standard DeviaƟon of flaƩened array, of each column, and
# each row\

# %%
import numpy as np

array = np.array([[1,-2,3],[-4,5,-6]])
# i. Element-wise absolute value
abs_array = np.abs(array)
print("Absolute values:\n", abs_array)

# ii. Percentiles
flattened = array.flatten()
print("\n25th,50th,75th percentiles of flattened array:",
      np.percentile(flattened,[25,50,75]))

print("\nPercentiles for each row:")
for i in range(array.shape[0]):
    print(f"Row {i}:",np.percentile(array[i,:],[25,50,75]))

print("\nPercentiles for each column:")
for i in range(array.shape[1]):
    print(f"Column {i}:",np.percentile(array[:,i],[25,50,75]))

# iii. Statistics
print("\nFlattened array - Mean:", np.mean(flattened),
      "Median:", np.median(flattened),
      "Std Dev:", np.std(flattened))
# each row
print("\nColumn-wise statistics:")
print("Means:", np.mean(array,axis=0))
print("Medians:", np.median(array,axis=0))
print("Std Devs:", np.std(array,axis=0))
# each col
print("\nRow-wise statistics:")
print("Means:", np.mean(array,axis=1))
print("Medians:", np.median(array,axis=1))
print("Std Devs:", np.std(array,axis=1))
# Out:
# Absolute values:
#  [[1 2 3]
#  [4 5 6]]
#
# 25th,50th,75th percentiles of flattened array: [-3.5 -0.5  2.5]
#
# Percentiles for each row:
# Row 0: [-0.5  1.   2. ]
# Row 1: [-5.  -4.   0.5]
#
# Percentiles for each column:
# Column 0: [-2.75 -1.5  -0.25]
# Column 1: [-0.25  1.5   3.25]
# Column 2: [-3.75 -1.5   0.75]
#
# Flattened array - Mean: -0.5 Median: -0.5 Std Dev: 3.8622100754188224
#
# Column-wise statistics:
# Means: [-1.5  1.5 -1.5]
# Medians: [-1.5  1.5 -1.5]
# Std Devs: [2.5 3.5 4.5]
#
# Row-wise statistics:
# Means: [ 0.66666667 -1.66666667]
# Medians: [ 1. -4.]
# Std Devs: [2.05480467 4.78423336]

# %% [markdown]
# Q.3 For the array: a = np.array([-1.8, -1.6, -0.5, 0.5,1.6, 1.8, 3.0]).
#
# i. Find floor, ceiling and truncated value, rounded values

# %%
a = np.array([-1.8,-1.6,-0.5,0.5,1.6,1.8,3.0])

# i. Various rounding functions
print("Floor values:", np.floor(a))
print("Ceiling values:", np.ceil(a))
print("Truncated values:", np.trunc(a))
print("Rounded values:", np.round(a))
# Out:
# Floor values: [-2. -2. -1.  0.  1.  1.  3.]
# Ceiling values: [-1. -1. -0.  1.  2.  2.  3.]
# Truncated values: [-1. -1. -0.  0.  1.  1.  3.]
# Rounded values: [-2. -2. -0.  0.  2.  2.  3.]

# %% [markdown]
# Q.4 WAP to swap two elements in a list in Python Using a Temporary Variable.

# %%
def swap_list_elements(lst,pos1,pos2):
    temp = lst[pos1]
    lst[pos1] = lst[pos2]
    lst[pos2] = temp
    print(f"List after swapping positions {pos1} and {pos2}: {lst}")

my_list = [10,20,30,40,50]
print(f"Original list: {my_list}")
swap_list_elements(my_list,1,3)
# Out:
# Original list: [10, 20, 30, 40, 50]
# List after swapping positions 1 and 3: [10, 40, 30, 20, 50]

# %% [markdown]
# Q.5 Write a Python program to swap two elements in a set by converƟng it to a list first.

# %%
def swap_set_elements(input_set,elem1,elem2):
    if elem1 not in input_set or elem2 not in input_set:
        print("One or both elements not found in the set")
        return input_set

    print(f"Original set: {input_set}")
    temp_list = list(input_set)
    idx1 = temp_list.index(elem1)
    idx2 = temp_list.index(elem2)
    temp=temp_list[idx1],
    temp_list[idx1] = temp_list[idx2],
    temp_list[idx2] = temp

    # Convert back to set
    swapped_set = set(temp_list)
    print(f"Set after swapping {elem1} and {elem2}: {swapped_set}")
    return swapped_set

my_set = {'apple','banana','cherry','date'}
swap_set_elements(my_set,'banana','date')
# Out:
# Original set: {'banana', 'apple', 'date', 'cherry'}
# Set after swapping banana and date: {('date',), 'apple', 'cherry', ('banana',)}
# {('banana',), ('date',), 'apple', 'cherry'}
