# %% [markdown]
# Assignment : 5
#
# Q.1 For the array gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]'), Find
#
# i. Sum of all elements
#
# ii. Sum of all elements row-wise
#
# iii. Sum of all elements column-wise

# %%
import numpy as np
gfg = np.matrix('[4,1,9;12,3,1;4,5,6]')
sum_elements = np.sum(gfg);

print(f"Sum of all elements of this array is : {sum_elements}")

sum1 = np.sum(gfg,axis=1)
print("Sum of all elements row-wise is : ")
print(sum1)

sum2 = np.sum(gfg,axis=0)
print(f"Sum of all elements row-wise is : {sum2}")
# Out:
# Sum of all elements of this array is : 45
# Sum of all elements row-wise is :
# [[14]
#  [16]
#  [15]]
# Sum of all elements row-wise is : [[20  9 16]]

# %% [markdown]
# Q.2 (a)For the array: array = np.array([10, 52, 62, 16, 16, 54, 453]), find
#
# i. Sorted array
#
# ii. Indices of sorted array
#
# iii. 4 smallest elements
#
# iv. 5 largest elements
#
#  (b) For the array: array = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0]), find
#
# i. Integer elements only
#
# ii. Float elements only

# %%
array = np.array([10,52,62,16,16,54,453])

# (a)
sort_array = np.sort(array)
print(f"Sorted array is : {sort_array}")
print()

sort_in = np.argsort(array)
print(f"Sorted indices is : {sort_in}")
print()

print(f"4 smallest elements are : {sort_array[:4]}")
print()

reverse = np.flip(sort_array);
print(f"5 largest elements are : {reverse[:5]}")
print()

# (b)
array1 = np.array([1.0,1.2,2.2,2.0,3.0,2.0])

integral = np.where(np.mod(array1,1)==0)
print(f"Indices where integral values exists in the given array are : {integral}")
print()

floating = np.where(np.mod(array1,1)!=0)
print(f"Indices where floating values exists in the given array are : {floating}")
# Out:
# Sorted array is : [ 10  16  16  52  54  62 453]
#
# Sorted indices is : [0 3 4 1 5 2 6]
#
# 4 smallest elements are : [10 16 16 52]
#
# 5 largest elements are : [453  62  54  52  16]
#
# Indices where integral values exists in the given array are : (array([0, 3, 4, 5]),)
#
# Indices where floating values exists in the given array are : (array([1, 2]),)

# %% [markdown]
# Q.3 You are given a weekly sales dataset and need to perform various operations
# using NumPy broadcasting.
#
# a) Generate your unique sales dataset:
#
#  Take the sum of the ASCII values of the initials of your first and last
# name. Call this value X. (If your initials are A B → ASCII sum = 65
# + 66 = 131 → sales = [131, 181, 231, 281, 331].)
#
#  Create a NumPy array sales with values [X, X+50, X+100, X+150,
# X+200].
#
# b) Compute your personalized tax rate as ((X % 5) + 5) / 100.
#
#  Use broadcasting to apply this tax rate to each sales value.
#
#
# c) Adjust sales based on discount:
#
#  If sales < X+100, apply a 5% discount.
#
#  If sales >= X+100, apply a 10% discount.
#
# d) Expand sales data for multiple weeks:
#
#  Create a 3×5 matrix representing three weeks of sales by stacking
# sales three times using broadcasting.
#
#  Increase sales by 2% per week using element-wise broadcasting.

# %%
X = ord('G') + ord('S')

sales = np.arange(X,X+(50*5),50)
print(sales);
print()

tax_rate = ((X%5)+5)/100

sales = sales+sales*tax_rate;
print(sales)
print()

sales = np.where(sales<X+100,sales*0.95,sales*0.90)
print(sales)
print()

new_sales = np.zeros((3,5))
new_sales = new_sales + sales
print(new_sales)
print()

new_sales = new_sales*1.02
print(new_sales)
# Out:
# [154 204 254 304 354]
#
# [167.86 222.36 276.86 331.36 385.86]
#
# [159.467 211.242 249.174 298.224 347.274]
#
# [[159.467 211.242 249.174 298.224 347.274]
#  [159.467 211.242 249.174 298.224 347.274]
#  [159.467 211.242 249.174 298.224 347.274]]
#
# [[162.65634 215.46684 254.15748 304.18848 354.21948]
#  [162.65634 215.46684 254.15748 304.18848 354.21948]
#  [162.65634 215.46684 254.15748 304.18848 354.21948]]

# %% [markdown]
# Q4. Generate x values using np.linspace() from -10 to 10 with 100 points. Use
# each function from the list below and compute y values using NumPy:
#
#  Y = x2
#
#  Y = sin(x)
#
#  Y = e^x
#
#  Y = log(|x| + 1)
#
# Plot the chosen function using Matplotlib. Add title, labels, and grid for clarity.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)

y1 = x**2
y2 = np.sin(x)
y3 = np.exp(x)
y4 = np.log(np.abs(x) + 1)

fig, axes = plt.subplots(2, 2, figsize=(10, 8))

axes[0, 0].plot(x, y1, 'r-', label=r'$y = x^2$')
axes[0, 0].set_title("Quadratic Function")
axes[0, 0].set_xlabel("x-axis")
axes[0, 0].set_ylabel("y-axis")
axes[0, 0].grid(True)
axes[0, 0].legend()

axes[0, 1].plot(x, y2, 'g-', label=r'$y = \sin(x)$')
axes[0, 1].set_title("Sine Function")
axes[0, 1].set_xlabel("x-axis")
axes[0, 1].set_ylabel("y-axis")
axes[0, 1].grid(True)
axes[0, 1].legend()

axes[1, 0].plot(x, y3, 'b-', label=r'$y = e^x$')
axes[1, 0].set_title("Exponential Function")
axes[1, 0].set_xlabel("x-axis")
axes[1, 0].set_ylabel("y-axis")
axes[1, 0].grid(True)
axes[1, 0].legend()

axes[1, 1].plot(x, y4, 'm-', label=r'$y = \log(|x| + 1)$')
axes[1, 1].set_title("Logarithmic Function")
axes[1, 1].set_xlabel("x-axis")
axes[1, 1].set_ylabel("y-axis")
axes[1, 1].grid(True)
axes[1, 1].legend()

plt.tight_layout()
plt.show()
